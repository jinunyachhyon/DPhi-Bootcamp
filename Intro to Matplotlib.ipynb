# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Standard_Metropolitan_Areas_Data-data.csv")

# %%
df.head()
# Out:
#    land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0       1384          78.1            12.3       25627          69678
# 1       3719          43.9             9.4       13326          43292
# 2       3553          37.4            10.7        9724          33731
# 3       3916          29.9             8.8        6402          24167
# 4       2480          31.5            10.5        8502          16751
#
#    graduates  work_force  income  region  crime_rate
# 0       50.1      4083.9   72100       1       75.55
# 1       53.9      3305.9   54542       2       56.03
# 2       50.6      2066.3   33216       1       41.32
# 3       52.2      1966.7   32906       2       67.38
# 4       66.1      1514.5   26573       4       80.19

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 1        3719          43.9             9.4       13326          43292
# 2        3553          37.4            10.7        9724          33731
# 3        3916          29.9             8.8        6402          24167
# 4        2480          31.5            10.5        8502          16751
# ..        ...           ...             ...         ...            ...
# 94       1511          38.7            10.7         348           1093
# 95       1543          39.6             8.1         159            481
# 96       1011          37.8            10.5         264            964
# 97        813          13.4            10.9         371           4355
# 98        654          28.8             3.9         140           1296
#
#     graduates  work_force  income  region  crime_rate
# 0        50.1      4083.9   72100       1       75.55
# ...

# %%
dfregion4=df[df.region==4]

# %%
dfregion1
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 0        1384          78.1            12.3       25627          69678
# 2        3553          37.4            10.7        9724          33731
# 8        3049          19.5            12.1        4005          21149
# 10       1008          16.6            10.3        4006          16704
# 24       2966          26.9            10.3        2053           6604
# 28       2624          30.4            12.2        1532           4730
# 36       2419          27.8             9.9        1250           2870
# 38       1951          28.4            14.5         696           4843
# 39       1490          33.1            11.9         827           3818
# 43        312          19.5             7.5         769           2463
# 46         47          41.9            11.9         745           3352
# 55        192          60.5            10.8         617           1789
# ...

# %%
dfregion2
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 1        3719          43.9             9.4       13326          43292
# 3        3916          29.9             8.8        6402          24167
# 9        4647          31.5             9.2        3916          12815
# 11       1519          31.8            10.5        4094          12545
# 15       1456          46.7            10.4        2484           8555
# 17       2149          29.8            10.6        2530           8354
# 19       3341          35.8            10.1        2289           7593
# 21       3072          68.0             9.3        2181           7497
# 23       2460          49.6             8.4        1874           7706
# 29       2187          47.0            10.2        1098           4342
# 35        903          37.3             9.6         948           4064
# 37        938          48.1             7.4         614           3016
# ...

# %%
dfregion3
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 5        2815          23.1             6.7        7340          16941
# 6        8360          46.3             8.2        4047          14347
# 7        6794          60.1             6.3        4562          14333
# 12       4326          23.6             7.3        3064           9976
# 16       2045          37.2            21.4        1949           8863
# 22       1967          51.1             8.8        2520           8467
# 26       1392          37.2             9.8        1579           6087
# 27       3358          35.1            11.3        1649           5512
# 30       3214          47.7             9.4        1285           3459
# 31       3491          48.5             9.7        1496           5620
# 32       4080          59.6             9.9        1597           7496
# 34       3199          80.6             8.7         983           4749
# ...

# %%
dfregion4
# Out:
#     land_area  percent_city  percent_senior  physicians  hospital_beds  \
# 4        2480          31.5            10.5        8502          16751
# 13        782          28.4             7.8        3119           8656
# 14       4226          38.1             9.8        3285           5392
# 18      27293          25.3            12.3        2018           6323
# 20       9155          53.8            11.1        2280           6450
# 25       3434          28.9             8.3        1844           3215
# 33        596         100.0             6.0        1260           2819
# 53       5966          39.5             9.6         737           1907
# 54       1863          50.4             7.7         674           2989
# 59       1676          36.6             9.2         505           3297
# 67       8152          22.3             9.1         405           1254
# 73       1758          56.8            11.5         565           2081
# ...

# %%
crmean4=dfregion4['crime_rate'].mean()

# %%
crmean1
# Out:
# 41.95190476190477

# %%
crmean2
# Out:
# 53.9744

# %%
crmean3
# Out:
# 58.26555555555555

# %%
crmean4
# Out:
# 41.95190476190477

# %%
CrimeRate=[crmean1,crmean2,crmean3,crmean4]

# %%
CrimeRate
# Out:
# [41.95190476190477, 53.9744, 58.26555555555555, 41.95190476190477]

# %%
region=['region 1','region 2','region 3','region 4']

# %%
region
# Out:
# ['region 1', 'region 2', 'region 3', 'region 4']

# %%
plt.plot(region,CrimeRate)#line plot
plt.show()

# %%
plt.bar(region,CrimeRate)#vertical bar plot
plt.show()

# %%
plt.barh(region,CrimeRate)#horizontal bar plot
plt.show()

# %%
plt.pie(CrimeRate,labels=region,autopct='%1.1f%%')#pie chart
plt.show()

# %%
#since region 3 has highest crime rate we can explode it
Explode=[0,0,0.1,0]
plt.pie(CrimeRate,labels=region,explode=Explode,autopct='%1.1f%%')#pie chart with explode
plt.show()
